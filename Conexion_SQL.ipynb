# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

from sqlalchemy import create_engine
import pyodbc

import pandas as pd
from conexion import engine

query = """
SELECT TOP 5 *
FROM dbo.DataCoSupplyChain
"""

df = pd.read_sql(query, engine)

print(df)
print(df.shape)
# Out:
#   estado_pedido tipo_transaccion  dias_envio_real  dias_envio_prog  \
# 0      COMPLETE            DEBIT                3                4
# 1      COMPLETE         TRANSFER                5                4
# 2      CANCELED             CASH                4                4
# 3      COMPLETE            DEBIT                3                4
# 4      COMPLETE          PAYMENT                2                4
#
#    beneficio_pedido  ventas_cliente    estado_entrega  riesgo_retraso  \
# 0         91.250000      314.640015  Advance shipping           False
# 1       -249.089996      311.359985     Late delivery            True
# 2       -247.779999      309.720001  Shipping on time           False
# 3         22.860001      304.809998  Advance shipping           False
# 4        134.210007      298.250000  Advance shipping           False
#
#         categoria ciudad_cliente  ... cantidad  ventas  total_item  \
# 0  Sporting Goods         Caguas  ...        1  327.75  314.640015
# 1  Sporting Goods         Caguas  ...        1  327.75  311.359985
# 2  Sporting Goods       San Jose  ...        1  327.75  309.720001
# 3  Sporting Goods    Los Angeles  ...        1  327.75  304.809998
# 4  Sporting Goods         Caguas  ...        1  327.75  298.250000
#
#   ganancia_pedido  region_destino   estado_destino  nombre_producto  \
# 0       91.250000  Southeast Asia  Java Occidental     Smart watch
# 1     -249.089996      South Asia         Rajastán     Smart watch
# 2     -247.779999      South Asia         Rajastán     Smart watch
# 3       22.860001         Oceania       Queensland     Smart watch
# 4      134.210007         Oceania       Queensland     Smart watch
#
#    precio_producto         fecha_envio      modo_envio
# 0           327.75 2018-02-03 22:56:00  Standard Class
# 1           327.75 2018-01-18 12:27:00  Standard Class
# 2           327.75 2018-01-17 12:06:00  Standard Class
# 3           327.75 2018-01-16 11:45:00  Standard Class
# 4           327.75 2018-01-15 11:24:00  Standard Class
#
# [5 rows x 28 columns]
# (5, 28)

# %% [markdown]
# Creamos la conexión

# %%
SERVER = "OMEGA-DELL"
DATABASE = "ML_DATABASE"
DRIVER = "ODBC Driver 18 for SQL Server"

connection_string = (
    f"mssql+pyodbc://@{SERVER}/{DATABASE}"
    f"?driver={DRIVER.replace(' ', '+')}"
    "&trusted_connection=yes"
    "&TrustServerCertificate=yes"
)

engine = create_engine(connection_string)

# %%
query = """
SELECT *
FROM dbo.DataCoSupplyChain
"""

df = pd.read_sql(query, engine)

# %%
print("Filas:", df.shape[0])
print("Columnas:", df.shape[1])
# Out:
# Filas: 180519
# Columnas: 28

# %%
df.tail()
# Out:
#        estado_pedido tipo_transaccion  dias_envio_real  dias_envio_prog  \
# 180514      CANCELED             CASH                4                4
# 180515      COMPLETE            DEBIT                3                2
# 180516      COMPLETE         TRANSFER                5                4
# 180517      COMPLETE          PAYMENT                3                4
# 180518      COMPLETE          PAYMENT                4                4
#
#         beneficio_pedido  ventas_cliente    estado_entrega  riesgo_retraso  \
# 180514         40.000000      399.980011  Shipping on time           False
# 180515       -613.770020      395.980011     Late delivery            True
# 180516        141.110001      391.980011     Late delivery            True
# 180517        186.229996      387.980011  Advance shipping           False
# 180518        168.949997      383.980011  Shipping on time           False
#
#        categoria ciudad_cliente  ... cantidad      ventas  total_item  \
# 180514   Fishing       Brooklyn  ...        1  399.980011  399.980011
# 180515   Fishing    Bakersfield  ...        1  399.980011  395.980011
# 180516   Fishing        Bristol  ...        1  399.980011  391.980011
# 180517   Fishing         Caguas  ...        1  399.980011  387.980011
# 180518   Fishing         Caguas  ...        1  399.980011  383.980011
#
#        ganancia_pedido region_destino     estado_destino  \
# 180514       40.000000   Eastern Asia           Shanghái
# 180515     -613.770020   Eastern Asia              Osaka
# 180516      141.110001        Oceania  Australia del Sur
# 180517      186.229996        Oceania  Australia del Sur
# 180518      168.949997     South Asia         Tamil Nadu
#
#                                   nombre_producto  precio_producto  \
# 180514  Field & Stream Sportsman 16 Gun Fire Safe       399.980011
# 180515  Field & Stream Sportsman 16 Gun Fire Safe       399.980011
# 180516  Field & Stream Sportsman 16 Gun Fire Safe       399.980011
# 180517  Field & Stream Sportsman 16 Gun Fire Safe       399.980011
# 180518  Field & Stream Sportsman 16 Gun Fire Safe       399.980011
#
#                fecha_envio      modo_envio
# 180514 2016-01-20 03:40:00  Standard Class
# 180515 2016-01-19 01:34:00    Second Class
# 180516 2016-01-20 21:00:00  Standard Class
# 180517 2016-01-18 20:18:00  Standard Class
# 180518 2016-01-19 18:54:00  Standard Class
#
# [5 rows x 28 columns]

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   estado_pedido         180519 non-null  object
#  1   tipo_transaccion      180519 non-null  object
#  2   dias_envio_real       180519 non-null  int64
#  3   dias_envio_prog       180519 non-null  int64
#  4   beneficio_pedido      180519 non-null  float64
#  5   ventas_cliente        180519 non-null  float64
#  6   estado_entrega        180519 non-null  object
#  7   riesgo_retraso        180519 non-null  bool
#  8   categoria             180519 non-null  object
#  9   ciudad_cliente        180519 non-null  object
#  10  pais_cliente          180519 non-null  object
#  11  latitud               180510 non-null  float64
#  12  longitud              180414 non-null  float64
#  13  ciudad_destino        180519 non-null  object
#  14  pais_destino          180519 non-null  object
#  15  fecha_pedido          180519 non-null  datetime64[ns]
#  16  precio_base           180519 non-null  float64
#  17  margen_ganancia_item  180519 non-null  float64
#  18  cantidad              180519 non-null  int64
#  19  ventas                180519 non-null  float64
#  20  total_item            180519 non-null  float64
#  21  ganancia_pedido       180519 non-null  float64
#  22  region_destino        180519 non-null  object
#  23  estado_destino        180519 non-null  object
#  24  nombre_producto       180519 non-null  object
#  25  precio_producto       180519 non-null  float64
#  26  fecha_envio           180519 non-null  datetime64[ns]
#  27  modo_envio            180519 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(10), int64(3), object(12)
# memory usage: 148.6 MB
