# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from sqlalchemy import text

import pyodbc

# %%
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server', 'PostgreSQL ODBC Driver(ANSI)', 'PostgreSQL ODBC Driver(UNICODE)', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
SERVER = r"OMEGA-DELL"
DATABASE = "BD_ML_RELACIONAL"

connection_string = (
    f"mssql+pyodbc://@{SERVER}/{DATABASE}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes"
    "&TrustServerCertificate=yes"
)

engine = create_engine(connection_string)

print("Conexión establecida correctamente.")
# Out:
# Conexión establecida correctamente.

# %%
query = text("EXEC sp_DatasetML")

df = pd.read_sql(query, engine)

df.head()
# Out:
#    id_pedido  id_raw        fecha_pedido         fecha_envio estado_pedido  \
# 0      21338   21338 2015-01-01 00:00:00 2015-01-03 00:00:00      CANCELED
# 1      88934   88934 2015-01-01 00:21:00 2015-01-04 00:21:00      COMPLETE
# 2      95636   95636 2015-01-01 00:21:00 2015-01-04 00:21:00      COMPLETE
# 3     113963  113963 2015-01-01 00:21:00 2015-01-04 00:21:00      COMPLETE
# 4     124256  124256 2015-01-01 01:03:00 2015-01-06 01:03:00      CANCELED
#
#      estado_entrega tipo_transaccion      modo_envio  dias_envio_real  \
# 0  Advance shipping             CASH  Standard Class                2
# 1  Advance shipping          PAYMENT  Standard Class                3
# 2  Advance shipping          PAYMENT  Standard Class                3
# 3  Advance shipping          PAYMENT  Standard Class                3
# 4     Late delivery             CASH  Standard Class                5
#
#    dias_envio_prog  ...    latitud   longitud      nombre_categoria  \
# 0                4  ...  35.776661 -81.362625      Camping & Hiking
# 1                4  ...  41.832722 -87.980484        Men's Footwear
# 2                4  ...  41.832722 -87.980484          Water Sports
# 3                4  ...  41.832722 -87.980484       Women's Apparel
# 4                4  ...  29.520010 -98.637413  Indoor/Outdoor Games
#
#                                  nombre_producto  ciudad_cliente  \
# 0  Diamondback Women's Serene Classic Comfort Bi         Hickory
# 1        Nike Men's CJ Elite 2 TD Football Cleat         Chicago
# 2                    Pelican Sunstream 100 Kayak         Chicago
# 3           Nike Men's Dri-FIT Victory Golf Polo         Chicago
# 4               O'Brien Men's Neoprene Life Vest     San Antonio
#
#    pais_cliente  ciudad_destino    estado_destino  pais_destino  \
# 0       EE. UU.     Mexico City  Distrito Federal        México
# 1       EE. UU.   Dos Quebradas         Risaralda      Colombia
# 2       EE. UU.   Dos Quebradas         Risaralda      Colombia
# 3       EE. UU.   Dos Quebradas         Risaralda      Colombia
# 4       EE. UU.   Dos Quebradas         Risaralda      Colombia
#
#     region_destino
# 0  Central America
# 1    South America
# 2    South America
# 3    South America
# 4    South America
#
# [5 rows x 30 columns]

# %%
print(df.shape)
# Out:
# (180519, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 30 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_pedido             180519 non-null  int64
#  1   id_raw                180519 non-null  int64
#  2   fecha_pedido          180519 non-null  datetime64[ns]
#  3   fecha_envio           180519 non-null  datetime64[ns]
#  4   estado_pedido         180519 non-null  object
#  5   estado_entrega        180519 non-null  object
#  6   tipo_transaccion      180519 non-null  object
#  7   modo_envio            180519 non-null  object
#  8   dias_envio_real       180519 non-null  int64
#  9   dias_envio_prog       180519 non-null  int64
#  10  precio_producto       180519 non-null  float64
#  11  precio_base           180519 non-null  float64
#  12  beneficio_pedido      180519 non-null  float64
#  13  ventas_cliente        180519 non-null  float64
#  14  margen_ganancia_item  180519 non-null  float64
#  15  cantidad              180519 non-null  int64
#  16  ventas                180519 non-null  float64
#  17  total_item            180519 non-null  float64
#  18  ganancia_pedido       180519 non-null  float64
#  19  riesgo_retraso        180519 non-null  bool
#  20  latitud               180510 non-null  float64
#  21  longitud              180414 non-null  float64
#  22  nombre_categoria      180519 non-null  object
#  23  nombre_producto       180519 non-null  object
#  24  ciudad_cliente        180519 non-null  object
#  25  pais_cliente          180519 non-null  object
#  26  ciudad_destino        180519 non-null  object
#  27  estado_destino        180519 non-null  object
#  28  pais_destino          180519 non-null  object
#  29  region_destino        180519 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(10), int64(5), object(12)
# memory usage: 40.1+ MB

# %%
df.isnull().sum()
# Out:
# id_pedido                 0
# id_raw                    0
# fecha_pedido              0
# fecha_envio               0
# estado_pedido             0
# estado_entrega            0
# tipo_transaccion          0
# modo_envio                0
# dias_envio_real           0
# dias_envio_prog           0
# precio_producto           0
# precio_base               0
# beneficio_pedido          0
# ventas_cliente            0
# margen_ganancia_item      0
# cantidad                  0
# ventas                    0
# total_item                0
# ganancia_pedido           0
# riesgo_retraso            0
# latitud                   9
# longitud                105
# nombre_categoria          0
# nombre_producto           0
# ciudad_cliente            0
# pais_cliente              0
# ciudad_destino            0
# estado_destino            0
# pais_destino              0
# region_destino            0
# dtype: int64

# %%
print("="*50)
print("DIMENSIONES")
print("="*50)

print(f"Filas: {df.shape[0]:,}")
print(f"Columnas: {df.shape[1]}")
# Out:
# ==================================================
# DIMENSIONES
# ==================================================
# Filas: 180,519
# Columnas: 30

# %%
df["estado_pedido"].value_counts()
# Out:
# estado_pedido
# COMPLETE    119550
# CANCELED     60969
# Name: count, dtype: int64

# %%
(
    df["estado_pedido"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)
# Out:
# estado_pedido
# COMPLETE    66.23
# CANCELED    33.77
# Name: proportion, dtype: float64
