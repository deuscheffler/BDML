# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# ## Objetivo
#
# Analizar la estructura, calidad y características del dataset **DataCoSupplyChain** almacenado en SQL Server, identificando valores nulos, duplicados, tipos de datos, distribuciones y posibles valores atípicos que puedan afectar el entrenamiento de los modelos de Machine Learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sqlalchemy import create_engine

# Configuración para mostrar todas las columnas
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ## Conexión a SQL

# %%
SERVER = "OMEGA-DELL"
DATABASE = "ML_DATABASE"
DRIVER = "ODBC Driver 18 for SQL Server"

connection_string = (
    f"mssql+pyodbc://@{SERVER}/{DATABASE}"
    f"?driver={DRIVER.replace(' ', '+')}"
    "&trusted_connection=yes"
    "&TrustServerCertificate=yes"
)

engine = create_engine(connection_string)

df = pd.read_sql(
    "SELECT * FROM dbo.DataCoSupplyChain",
    engine
)

# %%
print("DIMENSIONES DEL DATASET")


print(f"Filas    : {df.shape[0]:,}")
print(f"Columnas : {df.shape[1]}")
# Out:
# DIMENSIONES DEL DATASET
# Filas    : 180,519
# Columnas : 28
